# %% [markdown]
# # EDA — Brazilian E-Commerce (Olist)
#
# Explore the data to justify the chosen ML problem (low-review risk).
#
# - % of low reviews (≤2 stars)
# - Correlation between delivery delay and rating
# - Seller-level rating variance
# - Category-level rating trends
# - Region-level patterns
#
# Generate 5–7 clear insights.

# %%
# Load data (adjust path to Kaggle download)
# from src.data_loader import load_raw_data
# df = load_raw_data('path/to/olist')
